# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

movies = pd.read_csv('IMDB-Movie-data.csv', sep = ',')

# %%
#description of the data
movies.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
#number of rows and columns
movies.shape
# Out:
# (1000, 12)

# %%
movies.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
movies.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
novie = movies.rename(columns={"Runtime (Minutes)":"Runtime (Hours)"})

# %%
novie.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Hours)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
pd.to_datetime(novie['Runtime (Hours)'], unit='m').dt.strftime('%H:%M')
# Out:
# 0      02:01
# 1      02:04
# 2      01:57
# 3      01:48
# 4      02:03
# 5      01:43
# 6      02:08
# 7      01:29
# 8      02:21
# 9      01:56
# 10     02:13
# 11     02:07
# 12     02:13
# 13     01:47
# 14     01:49
# 15     01:27
# 16     02:19
# 17     02:03
# 18     01:58
# 19     01:56
# 20     02:00
# 21     02:17
# 22     01:48
# 23     01:32
# 24     02:00
# 25     01:23
# 26     02:39
# 27     01:39
# 28     01:40
# 29     01:55
#        ...
# 970    01:32
# 971    01:45
# 972    02:03
# 973    01:51
# 974    02:04
# 975    01:34
# 976    01:53
# 977    01:32
# 978    01:37
# 979    02:00
# 980    01:49
# 981    01:58
# 982    02:13
# 983    01:44
# 984    01:51
# 985    01:42
# 986    01:32
# 987    01:44
# 988    01:39
# 989    02:08
# 990    01:32
# 991    02:45
# 992    01:37
# 993    01:37
# 994    01:28
# 995    01:51
# 996    01:34
# 997    01:38
# 998    01:33
# 999    01:27
# Name: Runtime (Hours), Length: 1000, dtype: object

# %%
novie.sort_values('Runtime (Hours)', ascending=False).head(20)
# Out:
#      Rank                                     Title                     Genre  \
# 828   829                                Grindhouse    Action,Horror,Thriller
# 88     89                         The Hateful Eight       Crime,Drama,Mystery
# 965   966                             Inland Empire    Drama,Mystery,Thriller
# 311   312                            La vie d'Adèle             Drama,Romance
# 82     83                   The Wolf of Wall Street    Biography,Comedy,Crime
# 267   268                               Cloud Atlas              Drama,Sci-Fi
# 430   431                                  3 Idiots              Comedy,Drama
# 75     76  Pirates of the Caribbean: At World's End  Action,Adventure,Fantasy
# 271   272         The Hobbit: An Unexpected Journey         Adventure,Fantasy
# 36     37                              Interstellar    Adventure,Drama,Sci-Fi
# 425   426       The Curious Case of Benjamin Button     Drama,Fantasy,Romance
# ...

# %%
novie.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Hours)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014              121
# ...

# %% [markdown]
# # Are there any missing values?

# %%
#missing values
novie.isnull().sum()
#returns the sum of missing values in each column
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Hours)         0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
movies['Revenue (Millions)']
# Out:
# 0      333.13
# 1      126.46
# 2      138.12
# 3      270.32
# 4      325.02
# 5       45.13
# 6      151.06
# 7         NaN
# 8        8.01
# 9      100.01
# 10     234.02
# 11     169.27
# 12     532.17
# 13     248.75
# 14       2.87
# 15     368.31
# 16      67.12
# 17     162.16
# 18      51.69
# 19     100.50
# 20       7.22
# 21      47.70
# 22        NaN
# 23     153.69
# 24     103.14
# 25        NaN
# 26       6.50
# 27       0.01
# 28     113.08
# 29      54.65
#         ...
# 970     34.33
# 971     80.05
# 972     38.51
# 973     38.18
# 974      8.81
# 975     59.57
# 976       NaN
# 977       NaN
# 978       NaN
# 979      3.19
# 980     61.69
# 981     85.91
# 982     24.34
# 983     82.39
# 984     42.65
# 985     21.56
# 986     42.58
# 987     23.39
# 988       NaN
# 989     52.07
# 990     45.80
# 991      1.20
# 992      6.92
# 993     60.13
# 994     54.72
# 995       NaN
# 996     17.54
# 997     58.01
# 998       NaN
# 999     19.64
# ...

# %%
movies['Metascore']
# Out:
# 0      76.0
# 1      65.0
# 2      62.0
# 3      59.0
# 4      40.0
# 5      42.0
# 6      93.0
# 7      71.0
# 8      78.0
# 9      41.0
# 10     66.0
# 11     74.0
# 12     65.0
# 13     81.0
# 14     70.0
# 15     61.0
# 16     71.0
# 17     58.0
# 18     69.0
# 19     81.0
# 20     49.0
# 21     96.0
# 22     72.0
# 23     56.0
# 24     32.0
# 25      NaN
# 26      NaN
# 27      NaN
# 28     60.0
# 29     36.0
#        ...
# 970    62.0
# 971     NaN
# 972    47.0
# 973    52.0
# 974    73.0
# 975    37.0
# 976    39.0
# 977    38.0
# 978    48.0
# 979    70.0
# 980    44.0
# 981    33.0
# 982    56.0
# 983    30.0
# 984    47.0
# 985    31.0
# 986    50.0
# 987    30.0
# 988    89.0
# 989     NaN
# 990    44.0
# 991    42.0
# 992     NaN
# 993    37.0
# 994    48.0
# 995    45.0
# 996    46.0
# 997    50.0
# 998    22.0
# 999    11.0
# Name: Metascore, Length: 1000, dtype: float64

# %%
#Replacing missing values
movies.fillna('Unavailable')['Revenue (Millions)']
# Out:
# 0           333.13
# 1           126.46
# 2           138.12
# 3           270.32
# 4           325.02
# 5            45.13
# 6           151.06
# 7      Unavailable
# 8             8.01
# 9           100.01
# 10          234.02
# 11          169.27
# 12          532.17
# 13          248.75
# 14            2.87
# 15          368.31
# 16           67.12
# 17          162.16
# 18           51.69
# 19           100.5
# 20            7.22
# 21            47.7
# 22     Unavailable
# 23          153.69
# 24          103.14
# 25     Unavailable
# 26             6.5
# 27            0.01
# 28          113.08
# 29           54.65
#           ...
# 970          34.33
# 971          80.05
# 972          38.51
# 973          38.18
# 974           8.81
# 975          59.57
# 976    Unavailable
# 977    Unavailable
# 978    Unavailable
# 979           3.19
# 980          61.69
# 981          85.91
# 982          24.34
# 983          82.39
# 984          42.65
# 985          21.56
# ...

# %%
movies.fillna('Unavailable')['Metascore']
# Out:
# 0               76
# 1               65
# 2               62
# 3               59
# 4               40
# 5               42
# 6               93
# 7               71
# 8               78
# 9               41
# 10              66
# 11              74
# 12              65
# 13              81
# 14              70
# 15              61
# 16              71
# 17              58
# 18              69
# 19              81
# 20              49
# 21              96
# 22              72
# 23              56
# 24              32
# 25     Unavailable
# 26     Unavailable
# 27     Unavailable
# 28              60
# 29              36
#           ...
# 970             62
# 971    Unavailable
# 972             47
# 973             52
# 974             73
# 975             37
# 976             39
# 977             38
# 978             48
# 979             70
# 980             44
# 981             33
# 982             56
# 983             30
# 984             47
# 985             31
# ...

# %% [markdown]
# Basic Filtering

# %%
novie[novie['Rating'] > 5.0]
# Out:
#      Rank                                    Title  \
# 0       1                  Guardians of the Galaxy
# 1       2                               Prometheus
# 2       3                                    Split
# 3       4                                     Sing
# 4       5                            Suicide Squad
# 5       6                           The Great Wall
# 6       7                               La La Land
# 7       8                                 Mindhorn
# 8       9                       The Lost City of Z
# 9      10                               Passengers
# 10     11  Fantastic Beasts and Where to Find Them
# 11     12                           Hidden Figures
# 12     13                                Rogue One
# 13     14                                    Moana
# 14     15                                 Colossal
# 15     16                  The Secret Life of Pets
# 16     17                            Hacksaw Ridge
# ...

# %%
 novie[novie['Rating'] > 5.0]["Runtime (Hours)"].mean()
# Out:
# 113.88457502623295

# %%
from datetime import timedelta
str(timedelta(minutes=113.88))[:7]
# Out:
# '1:53:52'

# %%
novie[novie['Rating'] > 5.0]['Year'].mean()
# Out:
# 2012.7114375655824

# %%
Good_movies = novie[novie['Rating'] > 5.0]['Year'].head(10)

# %%
Good_movies
# Out:
# 0    2014
# 1    2012
# 2    2016
# 3    2016
# 4    2016
# 5    2016
# 6    2016
# 7    2016
# 8    2016
# 9    2016
# Name: Year, dtype: int64

# %%
movies['Year'].min()
# Out:
# 2006

# %%
Good_movies = novie[novie['Rating'] > 5.0].sort_values('Year', ascending=False).head(20)

# %%
Good_movies
# Out:
#      Rank                                              Title  \
# 999  1000                                         Nine Lives
# 748   749                              Ouija: Origin of Evil
# 264   265   Teenage Mutant Ninja Turtles: Out of the Shadows
# 734   735                                         Mr. Church
# 740   741                                           The Boss
# 259   260  Norman: The Moderate Rise and Tragic Fall of a...
# 258   259                                         Lights Out
# 741   742                                     Hands of Stone
# 747   748                                  Rules Don't Apply
# 756   757                                           Lavender
# 732   733                           This Beautiful Fantastic
# 757   758                                             Deuces
# 247   248                                 20th Century Women
# 242   243                                           Rock Dog
# ...

# %%
novie['Runtime (Hours)'].plot(kind='hist', bins=5)

# %%
#box plot
movies['Runtime (Minutes)'].plot(kind='box')
#green line represents the median

# %%
#How many movies that were made in 2016-2012
movies[['Year', 'Title',]].groupby('Year').count()
# Out:
#       Title
# Year
# 2006     44
# 2007     53
# 2008     52
# 2009     51
# 2010     60
# 2011     63
# 2012     64
# 2013     91
# 2014     98
# 2015    127
# 2016    297

# %%
movies[['Year', 'Title',]].groupby('Year').count().plot(kind='bar', title='Number of movies per Year')
plt.xlabel('Year')
plt.ylabel('Title')
# Out:
# Text(0, 0.5, 'Title')

# %%
movies[['Year', 'Genre']].groupby('Genre').count()
# Out:
#                             Year
# Genre
# Action                         2
# Action,Adventure               3
# Action,Adventure,Biography     2
# Action,Adventure,Comedy       14
# Action,Adventure,Crime         6
# Action,Adventure,Drama        18
# Action,Adventure,Family        4
# Action,Adventure,Fantasy      27
# Action,Adventure,Horror        2
# Action,Adventure,Mystery       5
# Action,Adventure,Romance       2
# Action,Adventure,Sci-Fi       50
# Action,Adventure,Thriller     11
# Action,Adventure,Western       2
# Action,Biography,Crime         1
# Action,Biography,Drama         8
# Action,Comedy                  6
# Action,Comedy,Crime           12
# Action,Comedy,Drama            1
# Action,Comedy,Family           1
# Action,Comedy,Fantasy          3
# Action,Comedy,Horror           2
# Action,Comedy,Mystery          1
# Action,Comedy,Romance          2
# Action,Comedy,Sci-Fi           1
# Action,Comedy,Sport            1
# Action,Crime,Drama            17
# ...

# %%
movies[['Runtime (Minutes)', 'Genre']].groupby('Genre').mean()
# Out:
#                             Runtime (Minutes)
# Genre
# Action                              88.000000
# Action,Adventure                   124.333333
# Action,Adventure,Biography         131.500000
# Action,Adventure,Comedy            109.642857
# Action,Adventure,Crime             116.500000
# Action,Adventure,Drama             124.166667
# Action,Adventure,Family            105.500000
# Action,Adventure,Fantasy           118.148148
# Action,Adventure,Horror            106.500000
# Action,Adventure,Mystery           128.600000
# Action,Adventure,Romance           117.500000
# Action,Adventure,Sci-Fi            127.360000
# Action,Adventure,Thriller          126.363636
# Action,Adventure,Western           141.000000
# Action,Biography,Crime              92.000000
# Action,Biography,Drama             125.875000
# Action,Comedy                      106.666667
# Action,Comedy,Crime                108.166667
# Action,Comedy,Drama                109.000000
# ...

# %%
#determine the top rated movie by rating for each genre
movies.sort_values('Rating', ascending=False).groupby('Genre')['Title', 'Rating'].first()
# Out:
#                                                                   Title  \
# Genre
# Action                                             Boyka: Undisputed IV
# Action,Adventure                                 The Amazing Spider-Man
# Action,Adventure,Biography                           The Lost City of Z
# Action,Adventure,Comedy                                        Deadpool
# Action,Adventure,Crime                                  Sherlock Holmes
# Action,Adventure,Drama                          Bahubali: The Beginning
# Action,Adventure,Family                                      Maleficent
# Action,Adventure,Fantasy     Star Wars: Episode VII - The Force Awakens
# Action,Adventure,Horror                                     World War Z
# Action,Adventure,Mystery                The Hunger Games: Catching Fire
# Action,Adventure,Romance                                       The Host
# Action,Adventure,Sci-Fi                                       Inception
# ...

# %%
#average rating of movies made after 2009
after = movies[movies['Year'] >= 2009]['Rating'].mean()

# %%
after
# Out:
# 6.673090481786134

# %%
#average rating of movies made after 2009
before = movies[movies['Year'] < 2009]['Rating'].mean()

# %%
before
# Out:
# 7.009395973154367

# %%
box = movies.boxplot(column='Year', by='Rating');#see if you can clean it up a little

# %%
corr = movies.select_dtypes(include = ['float64', 'int64']).iloc[:, 1:].corr()
plt.figure(figsize=(5, 5))
sns.heatmap(corr, vmax=1, square=True)

# %%
corr_dict = corr['Rating'].to_dict()

# %%
corr_dict
# Out:
# {'Year': -0.21121875660351452,
#  'Runtime (Minutes)': 0.39221424552505135,
#  'Rating': 1.0,
#  'Votes': 0.5115373197657569,
#  'Revenue (Millions)': 0.21765389419106002,
#  'Metascore': 0.6318965100387066}

# %% [markdown]
# The rating correlates strongly with Runtime, Votes

# %%
#determine the top rated movie by rating for each genre
movies.sort_values('Rating', ascending=False).groupby('Genre')['Title', 'Rating'].first()
# Out:
#                                                                   Title  \
# Genre
# Action                                             Boyka: Undisputed IV
# Action,Adventure                                 The Amazing Spider-Man
# Action,Adventure,Biography                           The Lost City of Z
# Action,Adventure,Comedy                                        Deadpool
# Action,Adventure,Crime                                  Sherlock Holmes
# Action,Adventure,Drama                          Bahubali: The Beginning
# Action,Adventure,Family                                      Maleficent
# Action,Adventure,Fantasy     Star Wars: Episode VII - The Force Awakens
# Action,Adventure,Horror                                     World War Z
# Action,Adventure,Mystery                The Hunger Games: Catching Fire
# Action,Adventure,Romance                                       The Host
# Action,Adventure,Sci-Fi                                       Inception
# ...

# %%
#How many movies did each actor act in 
def repp(string):
    return string.replace("[","").replace("]","").replace("u'","").replace("',",",")[:-1]
    
movies_series = movies['Actors'].apply(repp)
    
actor_dict = {}
for actor in actors:
    for name in actor:
        if name in actor_dict:
            actor_dict[name] +=1
        else:
            actor_dict[name] = 1

# %%
actor_dict
# Out:
# {'Chris Pratt': 7,
#  'Vin Diesel': 7,
#  'Bradley Cooper': 11,
#  'Zoe Saldan': 2,
#  'Noomi Rapace': 5,
#  'Logan Marshall-Green': 2,
#  'Michael Fassbender': 12,
#  'Charlize Thero': 1,
#  'James McAvoy': 8,
#  'Anya Taylor-Joy': 3,
#  'Haley Lu Richardson': 2,
#  'Jessica Sul': 1,
#  'Matthew McConaughey': 8,
#  'Reese Witherspoon': 4,
#  'Seth MacFarlane': 4,
#  'Scarlett Johansso': 1,
#  'Will Smith': 10,
#  'Jared Leto': 3,
#  'Margot Robbie': 5,
#  'Viola Davi': 1,
#  'Matt Damon': 10,
#  'Tian Jing': 1,
#  'Willem Dafoe': 5,
#  'Andy La': 1,
#  'Ryan Gosling': 10,
#  'Emma Stone': 9,
#  'Rosemarie DeWitt': 1,
#  'J.K. Simmon': 1,
#  'Essie Davis': 2,
#  'Andrea Riseborough': 2,
#  'Julian Barratt': 1,
#  'Kenneth Branag': 2,
#  'Charlie Hunnam': 2,
#  'Robert Pattinson': 6,
#  'Sienna Miller': 5,
#  'Tom Hollan': 1,
#  'Jennifer Lawrence': 10,
#  'Michael Sheen': 3,
#  'Laurence Fishburn': 1,
#  'Eddie Redmayne': 4,
#  'Katherine Waterston': 1,
#  'Alison Sudol': 1,
# ...
